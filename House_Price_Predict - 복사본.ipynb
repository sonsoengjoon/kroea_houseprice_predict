# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/house_info_update1.csv", encoding= 'utf-8-sig', thousands=',')

# %%
# donli, danjiname, doro 삭제

# %%
real_market = df['market'] // 10
df['real_market'] = real_market

# %%
real_school = df['school'] // 20
df['real_scholl'] = real_school

# %%
real_station = df['station'] // 10
df['real_station'] = real_station

# %%
df = df.drop(['amenities'],axis=1)

# %%
df = df.drop(['danjicode'], axis=1)

# %%
df = df.drop(['market', 'school', 'station', 'nambang', 'sigog', 'siheg', 'gukag', 'donli','danjiname'], axis=1)

# %%
df.head(20)
# Out:
#          danjigubn  sedesu  eill  guard  clean       food  water  ellbe  gisa  \
# 0              아파트      69   1.0    3.0    1.0        NaN  부스타방식    2.0   0.0
# 1              NaN     116   NaN    NaN    NaN        NaN    NaN    0.0   NaN
# 2              NaN     122  16.0    NaN    NaN        NaN    NaN    NaN   NaN
# 3              NaN     136   3.0    0.0    2.0     차량수거방식  부스타방식    5.0  60.0
# 4              아파트     114   1.0    2.0    1.0  음식물쓰레기종량제  압력탱크식    3.0   0.0
# 5              NaN     148   1.0    2.0    1.0         기타  수도직결식    5.0  13.0
# 6              NaN     111   NaN    NaN    NaN        NaN    NaN    NaN   NaN
# 7              아파트     115   2.0    2.0    1.0  음식물쓰레기종량제  고가수조식    5.0  27.0
# 8              NaN     136   NaN    NaN    NaN        NaN    NaN    NaN   NaN
# 9   도시형 생활주택(주상복합)     187   0.0    2.0    1.0   거점장비수거방식  부스타방식    2.0   8.0
# 10            주상복합     108  11.0    3.0    4.0  음식물쓰레기종량제  부스타방식    2.0   0.0
# 11             아파트     128   NaN    NaN    NaN        NaN    NaN    NaN   NaN
# 12             NaN      96   4.0    2.0    1.0     차량수거방식  부스타방식    3.0   7.0
# 13             NaN      88   3.0    2.0    1.0     차량수거방식  부스타방식    3.0  30.0
# 14             아파트     104   NaN    NaN    NaN        NaN    NaN    NaN   NaN
# 15             아파트     104   NaN    NaN    NaN        NaN    NaN    NaN   NaN
# 16             아파트     127   NaN    NaN    NaN        NaN    NaN    NaN   NaN
# 17             아파트     109   NaN    NaN    NaN        NaN    NaN    NaN   NaN
# 18             아파트     115   1.0    2.0    1.0  음식물쓰레기종량제  부스타방식    4.0  78.0
# 19             아파트     118   1.0    2.0    1.0     차량수거방식  부스타방식    6.0  38.0
#
#      giha  ...                   doro amenitiesCnt price  bank  café  \
# 0    76.0  ...   서울특별시 광진구 아차산로36길 13            4  3689    26    87
# 1     NaN  ...   서울특별시 서초구 방배로3길 10-3            0  4627     9    31
# 2     NaN  ...      서울특별시 마포구 백범로 202            1  3988    45   145
# 3   124.0  ...     서울특별시 강서구 공항대로 637            3  3632    21    46
# 4   124.0  ...      서울특별시 강서구 양천로 497            4  2815    21    47
# 5   156.0  ...   서울특별시 강서구 등촌로13자길 74            4  1748     7    11
# 6     NaN  ...   서울특별시 서대문구 수색로 147-1            0  2669     2    14
# 7    93.0  ...  서울특별시 노원구 동일로239나길 31            3  2011    16    51
# 8     NaN  ...   서울특별시 강남구 언주로122길 25            0  5417    33   119
# 9    94.0  ...  서울특별시 도봉구 도봉로150다길 28            2  2876    23    45
# 10  248.0  ...      서울특별시 관악구 관악로 195            1  2334    35   127
# 11    NaN  ...    서울특별시 마포구 동교로39길 11            0  3357    17   456
# 12  104.0  ...  서울특별시 동대문구 한천로58길 181            5  2405     6    12
# 13   58.0  ...     서울특별시 마포구 독막로42길 5            3  5281    47   185
# 14    NaN  ...     서울특별시 성북구 종암로9길 71            0  3539    15    27
# 15    NaN  ...     서울특별시 성북구 종암로9길 71            0  3539    15    27
# 16    NaN  ...      서울특별시 관악구 호암로 541            0  2095    10    13
# 17    NaN  ...     서울특별시 관악구 호암로16길 5            0  2409     7     7
# 18   52.0  ...    서울특별시 노원구 석계로13길 35            2  2117    15    41
# 19   92.0  ...    서울특별시 관악구 관악로28길 80            4  2295    13    58
#
#     hospital   ipji  real_market  real_scholl  real_station
# 0          40   283            3            4             2
# 1          18   158            4            2             2
# 2         106   596            3            1            25
# 3          37   184            1            1             5
# 4          64   422           10            7             5
# 5           0   118            2            4             0
# 6           5   231            4            5             7
# 7          33   180            4            1             2
# 8          92   294            3            1             0
# 9          51   289            3            2            10
# 10        125   437            4            3             5
# 11         31   584            2            3             0
# 12          7    95            3            1             2
# 13        101   503            5            3             6
# 14         21   123            2            2             0
# 15         21   123            2            2             0
# 16          3   136            1            5             0
# 17          3    87            1            3             0
# 18          9   245            4            5             4
# 19         49   240            2            5             0
#
# [20 rows x 22 columns]

# %%
# gu_df = df['doro'].str.split(' ').str[1]

# %%
# gu_df = pd.DataFrame(gu_df)

# %%
# gu_df.columns = ['gu']

# %%
# df = pd.concat([df, gu_df], axis =1)

# %%
df = df.drop(['doro'], axis=1)

# %%
df.head(2)
# Out:
#   danjigubn  sedesu  eill  guard  clean food  water  ellbe  gisa  giha  ...  \
# 0       아파트      69   1.0    3.0    1.0  NaN  부스타방식    2.0   0.0  76.0  ...
# 1       NaN     116   NaN    NaN    NaN  NaN    NaN    0.0   NaN   NaN  ...
#
#    gucha amenitiesCnt  price  bank  café  hospital   ipji  real_market  \
# 0      무            4   3689    26    87         40   283            3
# 1    NaN            0   4627     9    31         18   158            4
#
#    real_scholl  real_station
# 0            4             2
# 1            2             2
#
# [2 rows x 21 columns]

# %%
#df = df.drop(['gukag'], axis=1)

# %%
df.columns
# Out:
# Index(['danjigubn', 'sedesu', 'eill', 'guard', 'clean', 'food', 'water',
#        'ellbe', 'gisa', 'giha', 'cctv', 'gucha', 'amenitiesCnt', 'price',
#        'bank', 'café', 'hospital ', 'ipji', 'real_market', 'real_scholl',
#        'real_station'],
#       dtype='object')

# %%
df.describe()
# Out:
#             sedesu         eill        guard        clean        ellbe  \
# count  2453.000000  2367.000000  2364.000000  2363.000000  2339.000000
# mean    555.627803     6.373638     8.842640     5.856369    13.357845
# std     606.883995     5.363804    12.421151     6.571119    14.537546
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     204.000000     4.000000     3.000000     2.000000     5.000000
# 50%     355.000000     5.000000     5.000000     4.000000     9.000000
# 75%     660.000000     8.000000    10.000000     7.000000    17.000000
# max    6864.000000    61.000000   234.000000    80.000000   207.000000
#
#               gisa         giha         cctv  amenitiesCnt         price  \
# count  2360.000000  2356.000000  2355.000000   2453.000000   2453.000000
# mean    186.560169   422.294143   105.732187      4.586221   3527.389319
# std     364.334105   662.282921   137.458456      2.126027   1623.105739
# min       0.000000     0.000000     0.000000      0.000000   1039.000000
# 25%      13.000000    95.000000    37.000000      3.000000   2366.000000
# 50%      66.000000   220.000000    64.000000      4.000000   3140.000000
# 75%     193.000000   510.000000   121.000000      6.000000   4218.000000
# max    4500.000000  9486.000000  2150.000000     11.000000  13091.000000
#
#               bank         café    hospital          ipji  real_market  \
# count  2453.000000  2453.000000  2453.000000  2453.000000  2453.000000
# mean     16.104770    48.852833    31.763555   212.770893     3.758663
# std      10.358069    43.422832    29.668690   102.004676     2.114304
# min       0.000000     0.000000     0.000000     4.000000     0.000000
# 25%       9.000000    22.000000    13.000000   146.000000     2.000000
# 50%      14.000000    37.000000    25.000000   198.000000     3.000000
# 75%      21.000000    61.000000    42.000000   262.000000     5.000000
# max      74.000000   555.000000   380.000000   875.000000    13.000000
#
#        real_scholl  real_station
# count  2453.000000   2453.000000
# mean      2.850387      2.145536
# std       1.814624      2.871290
# min       0.000000      0.000000
# 25%       2.000000      0.000000
# 50%       3.000000      2.000000
# 75%       4.000000      4.000000
# max      10.000000     25.000000

# %%
df.isnull().sum()
# Out:
# danjigubn        48
# sedesu            0
# eill             86
# guard            89
# clean            90
# food            157
# water           104
# ellbe           114
# gisa             93
# giha             97
# cctv             98
# gucha           101
# amenitiesCnt      0
# price             0
# bank              0
# café              0
# hospital          0
# ipji              0
# real_market       0
# real_scholl       0
# real_station      0
# dtype: int64

# %%
# df = df.dropna(subset=['ellbe', 'gisa', 'giha'])

# %%
df = df.dropna(thresh=18)

# %%
df.isnull().sum()
# Out:
# danjigubn       19
# sedesu           0
# eill             0
# guard            1
# clean            0
# food            59
# water            6
# ellbe           26
# gisa             2
# giha             1
# cctv             1
# gucha            7
# amenitiesCnt     0
# price            0
# bank             0
# café             0
# hospital         0
# ipji             0
# real_market      0
# real_scholl      0
# real_station     0
# dtype: int64

# %%
# 나중에 수치데이터로 바꿔줘야 할듯

# %%
df.loc[:,['danjigubn']] = df.loc[:,['danjigubn']].fillna('아파트')

# %%
# df['sigog'] = df['sigog'].str.replace('주','')

# %%
# df["sigog"] = df["sigog"].str.replace(pat=r'[^\w]', repl=r'', regex=True)

# %%
df = df.dropna()
df.count()
# Out:
# danjigubn       2264
# sedesu          2264
# eill            2264
# guard           2264
# clean           2264
# food            2264
# water           2264
# ellbe           2264
# gisa            2264
# giha            2264
# cctv            2264
# gucha           2264
# amenitiesCnt    2264
# price           2264
# bank            2264
# café            2264
# hospital        2264
# ipji            2264
# real_market     2264
# real_scholl     2264
# real_station    2264
# dtype: int64

# %%
# df['sigog'].value_counts()[:50]

# %%
#df.loc[~((df['sigog'] == '현대건설') | (df['sigog'] == '삼성물산') | (df['sigog']=='현대산업개발') | (df['sigog'] == '대우건설')), 'sigog'] = "other"

# %%
# df['sigog'].value_counts()

# %%
categories = df.columns[df.dtypes=="object"]
print(categories)
# Out:
# Index(['danjigubn', 'food', 'water', 'gucha'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for cat in categories:
    le = LabelEncoder()
    print(cat)
    if df[cat].dtypes == "object":
        le = le.fit(df[cat])
        df[cat] = le.transform(df[cat])
# Out:
# danjigubn
# food
# water
# gucha

# %%
df.dtypes
# Out:
# danjigubn         int32
# sedesu            int64
# eill            float64
# guard           float64
# clean           float64
# food              int32
# water             int32
# ellbe           float64
# gisa            float64
# giha            float64
# cctv            float64
# gucha             int32
# amenitiesCnt      int64
# price             int64
# bank              int64
# café              int64
# hospital          int64
# ipji              int64
# real_market       int64
# real_scholl       int64
# real_station      int64
# dtype: object

# %%
df
# Out:
#       danjigubn  sedesu  eill  guard  clean  food  water  ellbe  gisa   giha  \
# 3             1     136   3.0    0.0    2.0     3      2    5.0  60.0  124.0
# 4             1     114   1.0    2.0    1.0     2      4    3.0   0.0  124.0
# 5             1     148   1.0    2.0    1.0     1      3    5.0  13.0  156.0
# 7             1     115   2.0    2.0    1.0     2      0    5.0  27.0   93.0
# 9             0     187   0.0    2.0    1.0     0      2    2.0   8.0   94.0
# ...         ...     ...   ...    ...    ...   ...    ...    ...   ...    ...
# 2446          1     189   3.0    2.0    3.0     0      2   13.0  20.0  249.0
# 2447          1     126   3.0    2.0    2.0     2      2    3.0  20.0  213.0
# 2448          1     334   5.0    4.0    4.0     0      2   20.0  49.0  497.0
# 2449          1     412   5.0    4.0    5.0     0      2   21.0  37.0  493.0
# 2450          1     426   5.0    5.0    4.0     2      2   27.0   0.0  495.0
#
#       ...  gucha  amenitiesCnt  price  bank  café  hospital   ipji  \
# 3     ...      0             3   3632    21    46         37   184
# 4     ...      0             4   2815    21    47         64   422
# 5     ...      0             4   1748     7    11          0   118
# 7     ...      0             3   2011    16    51         33   180
# 9     ...      0             2   2876    23    45         51   289
# ...   ...    ...           ...    ...   ...   ...        ...   ...
# 2446  ...      1             5   2605     2    16          0    48
# 2447  ...      1             6   2435     1     3          0    24
# 2448  ...      1             7   2435     2     4          1    57
# 2449  ...      0             7   2746     1     7          0    38
# 2450  ...      0             8   2801     2    11          0    83
#
#       real_market  real_scholl  real_station
# 3               1            1             5
# 4              10            7             5
# 5               2            4             0
# 7               4            1             2
# 9               3            2            10
columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_corr, vmax=1, vmin=-1, center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
train_df_le = df[~df['price'].isnull()]
test_df_le = df[df['price'].isnull()]

# %%
import lightgbm as lgb

# %%
from sklearn.model_selection import KFold
folds = 3
kf = KFold(n_splits = folds)

# %%
lgbm_params = {
    "objective":"regression",
    "random_seed":1234
}

# %%
train_X = train_df_le.drop(['price'], axis=1)
train_Y = train_df_le['price']

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

models = []
rmses = []
oof = np.zeros(len(train_X))

for train_index, val_index in kf.split(train_X):
    X_train = train_X.iloc[train_index]
    X_valid = train_X.iloc[val_index]
    y_train = train_Y.iloc[train_index]
    y_valid = train_Y.iloc[val_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
    
    model_lgb = lgb.train(lgbm_params,
                         lgb_train,
                          valid_sets = lgb_eval,
                         num_boost_round=100,
                         early_stopping_rounds=20,
                         verbose_eval = 10)
    
    y_pred = model_lgb.predict(X_valid, num_iteration=model_lgb.best_iteration)
    tmp_rmse = np.sqrt(mean_squared_error(np.log(y_valid),np.log(y_pred)))
    print(tmp_rmse)
    
    models.append(model_lgb)
    rmses.append(tmp_rmse)
    oof[val_index] = y_pred
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000348 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1759
# [LightGBM] [Info] Number of data points in the train set: 1509, number of used features: 20
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 3285.288933
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 3.54759e+06
# [20]	valid_0's l2: 3.291e+06
# [30]	valid_0's l2: 3.16987e+06
# [40]	valid_0's l2: 3.13729e+06
# [50]	valid_0's l2: 3.1219e+06
# [60]	valid_0's l2: 3.11847e+06
# [70]	valid_0's l2: 3.13005e+06
# Early stopping, best iteration is:
# [54]	valid_0's l2: 3.1058e+06
# 0.3964318183887041
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000232 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1798
# [LightGBM] [Info] Number of data points in the train set: 1509, number of used features: 20
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 3722.620278
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 2.04598e+06
# [20]	valid_0's l2: 1.99073e+06
# [30]	valid_0's l2: 2.004e+06
# [40]	valid_0's l2: 1.9918e+06
# Early stopping, best iteration is:
# [22]	valid_0's l2: 1.98507e+06
# 0.4031529973091428
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1777
# [LightGBM] [Info] Number of data points in the train set: 1510, number of used features: 20
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 3610.884106
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 1.54573e+06
# [20]	valid_0's l2: 1.6651e+06
# Early stopping, best iteration is:
# [4]	valid_0's l2: 1.42406e+06
# 0.3479522907527608

# %%
for model in models:
    lgb.plot_importance(model, importance_type='gain', max_num_features=5)

# %%
actual_pred_df = pd.DataFrame({
    "actual": train_Y,
    "pred": oof
})

# %%
import matplotlib as plt

actual_pred_df.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>
